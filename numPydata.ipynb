# %%
import numpy
import matplotlib.pyplot as plt
from scipy import stats
#creates an array containing 250 random floats between 0 and 5

# a = numpy.random.uniform(0.0, 5.0, 250)

#draws a histogram with the data collected
# plt.hist(a,5)
# plt.show()

#creates an array with 100000 random numbers, and display them using a histogram with 100 bars:

# b = numpy.random.uniform(0.0, 5.0, 100000)
# plt.hist(b,100)
# plt.show()

# x = [5,7,8,7,2,17,2,9,4,11,12,9,6]

# y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# plt.scatter(x,y)
# plt.show()

# s = numpy.random.normal(5.0, 1.0, 1000)
# m = numpy.random.normal(10.0, 2.0, 1000)

# plt.scatter(s,m)
# plt.show()

# 
# **linear regression**

# slope,intercept,r,p,std_err = stats.linregress(x,y)

# def myfunc(x):
#     return slope * x + intercept

# mymodel = list(map(myfunc, x))

# plt.scatter(x,y)
# plt.plot(x, mymodel)
# plt.show()

#**r**
# slope, intercept, r, p, std_err = stats.linregress(x,y)
# print(r)

#**predict future values***
# def myfunc(x):
#     return slope * x + intercept
# speed = myfunc(10)

# print(speed)

#**polynomial regression**

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

# plt.scatter(x, y)
# plt.show()

mymodel = numpy.poly1d(numpy.polyfit(x,y,3))
myline = numpy.linspace(1,22,100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
